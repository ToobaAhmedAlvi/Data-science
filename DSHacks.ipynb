# %%
import pandas as pd

# %%
data = pd.read_csv('Test_data.csv')
data.transpose()
# Out:
#                            0           1           2           3    \
# age                         65          36          37     30.0651
# job_type               retired  management  management  management
# marital_status         married     married     married      single
# education_level      secondary    tertiary    tertiary    tertiary
# default_or_not               0           0           0           0
# balance_amt              20806         900        6771           0
# household_insurance          0           1           0           0
# car_loan                     0           0           0           0
# communication        telephone         NaN    cellular    cellular
# last_contact_day             8          15           7          14
# last_contact_month         apr         may         sep         may
# no_of_contacts               2           2           1           2
# days_passed                 -1          -1         186          -1
# ...

# %%
data.dtypes
# Out:
# age                    float64
# job_type                object
# marital_status          object
# education_level         object
# default_or_not           int64
# balance_amt            float64
# household_insurance      int64
# car_loan                 int64
# communication           object
# last_contact_day         int64
# last_contact_month      object
# no_of_contacts           int64
# days_passed              int64
# prev_attempts            int64
# Outcome                 object
# call_start              object
# call_end                object
# dtype: object

# %% [markdown]
# # SELECT DATATYPES

# %%
category_select = data.select_dtypes("object").head()
display(category_select.head())
# Out:
#      job_type marital_status education_level communication last_contact_month  \
# 0     retired        married       secondary     telephone                apr
# 1  management        married        tertiary           NaN                may
# 2  management        married        tertiary      cellular                sep
# 3  management         single        tertiary      cellular                may
# 4  management        married        tertiary      cellular                jul
#
#    Outcome call_start  call_end
# 0      NaN   12:22:13  12:30:56
# 1      NaN   17:59:45  18:07:40
# 2  success   14:05:19  14:10:56
# 3      NaN   17:33:27  09:47:54
# 4      NaN   14:40:26  14:41:31

# %%
category_number = data.select_dtypes("number").head()
display(category_number.head())
# Out:
#          age  default_or_not  balance_amt  household_insurance  car_loan  \
# 0  65.000000               0      20806.0                    0         0
# 1  36.000000               0        900.0                    1         0
# 2  37.000000               0       6771.0                    0         0
# 3  30.065066               0          0.0                    0         0
# 4  41.000000               0        328.0                    1         0
#
#    last_contact_day  no_of_contacts  days_passed  prev_attempts
# 0                 8               2           -1              0
# 1                15               2           -1              0
# 2                 7               1          186              1
# 3                14               2           -1              0
# 4                29              12           -1              0

# %% [markdown]
# # ADD COLUMNS TO A DATASET

# %%
data['Car'] = ['car ' + str(i) for i in range(1,936)]
display(data.head())
# Out:
#          age    job_type marital_status education_level  default_or_not  \
# 0  65.000000     retired        married       secondary               0
# 1  36.000000  management        married        tertiary               0
# 2  37.000000  management        married        tertiary               0
# 3  30.065066  management         single        tertiary               0
# 4  41.000000  management        married        tertiary               0
#
#    balance_amt  household_insurance  car_loan communication  last_contact_day  \
# 0      20806.0                    0         0     telephone                 8
# 1        900.0                    1         0           NaN                15
# 2       6771.0                    0         0      cellular                 7
# 3          0.0                    0         0      cellular                14
# 4        328.0                    1         0      cellular                29
#
# ...

# %% [markdown]
# ###  BRING LAST COLUMN TO FIRST POSITION

# %%
cols = data.columns.tolist()
data1 = data[['Car','car_loan','age', 'job_type','education_level', 'balance_amt', 'household_insurance']]

# %%
data1
# Out:
#          Car  car_loan        age     job_type education_level  balance_amt  \
# 0      car 1         0  65.000000      retired       secondary      20806.0
# 1      car 2         0  36.000000   management        tertiary        900.0
# 2      car 3         0  37.000000   management        tertiary       6771.0
# 3      car 4         0  30.065066   management        tertiary          0.0
# 4      car 5         0  41.000000   management        tertiary        328.0
# ..       ...       ...        ...          ...             ...          ...
# 930  car 931         1  31.000000  blue-collar       secondary        152.0
# 931  car 932         0  30.000000   technician       secondary         53.0
# 932  car 933         0  42.000000   management        tertiary         36.0
# 933  car 934         0  46.000000     services       secondary       2948.0
# 934  car 935         0  54.000000  blue-collar       secondary        548.0
#
#      household_insurance
# 0                      0
# ...

# %% [markdown]
# ### WIDE DATA FORMAT

# %%
data1.head(20)
# Out:
#        Car        age     job_type education_level   balance_amt  \
# 0    car 1  65.000000      retired       secondary  20806.000000
# 1    car 2  36.000000   management        tertiary    900.000000
# 2    car 3  37.000000   management        tertiary   6771.000000
# 3    car 4  30.065066   management        tertiary      0.000000
# 4    car 5  41.000000   management        tertiary    328.000000
# 5    car 6  33.000000   management        tertiary      0.000000
# 6    car 7  46.000000   management        tertiary   7331.000000
# 7    car 8  39.126336       admin.       secondary    891.034255
# 8    car 9  58.000000      retired         primary    565.000000
# 9   car 10  48.000000   technician       secondary  10655.000000
# 10  car 11  31.000000       admin.       secondary     35.000000
# 11  car 12  56.228467   technician       secondary    247.789089
# 12  car 13  46.000000       admin.       secondary    659.000000
# ...

# %% [markdown]
# ### LONG DATA FORMAT

# %%
tidy = pd.melt(data,
               id_vars = ['Car','age'],value_vars="household_insurance",
               var_name ='0 for bought /1 for not' ,value_name = "insurance_value")
tidy.head(10)
# Out:
#       Car        age 0 for bought /1 for not  insurance_value
# 0   car 1  65.000000     household_insurance                0
# 1   car 2  36.000000     household_insurance                1
# 2   car 3  37.000000     household_insurance                0
# 3   car 4  30.065066     household_insurance                0
# 4   car 5  41.000000     household_insurance                1
# 5   car 6  33.000000     household_insurance                0
# 6   car 7  46.000000     household_insurance                0
# 7   car 8  39.126336     household_insurance                0
# 8   car 9  58.000000     household_insurance                0
# 9  car 10  48.000000     household_insurance                0

# %% [markdown]
# # SPLITTING A COLUMN INTO 2

# %%
data1['vehicle'] = data1['Car'].str.split(' ', expand = True)[0]
data1['car_number'] = data1['Car'].str.split(' ', expand = True)[1]
data1
# Out:
# <ipython-input-52-519c70c36f16>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['vehicle'] = data1['Car'].str.split(' ', expand = True)[0]
# <ipython-input-52-519c70c36f16>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['car_number'] = data1['Car'].str.split(' ', expand = True)[1]
#          Car        age     job_type education_level  balance_amt  \
# 0      car 1  65.000000      retired       secondary      20806.0
# ...

# %% [markdown]
# # EXTRACT EMAIL FROM TEXT

# %%
passage = """The E-Book looks amazing and I would like a copy of it, here is my e-mail id xyz@gmail.com | 
        Hi, I am looking for a job in data science field, please send me the E-book and kindly suggest
        how to move forward, thanks ab_c@gmail.com"""

# %%
import re

# %%
re.findall(r"([\w.-]+@[\w.-]+)", passage)
# Out:
# ['xyz@gmail.com', 'ab_c@gmail.com']

# %%
import pandas as pd
import glob
from os.path import isfile, join

# %%
# glob finds all the pathnames matching a specified string
allFiles = glob.glob("./****_data.csv")
allFiles
# Out:
# ['.\\Test_data.csv', '.\\Train_data.csv']

# %%
# Read multiple files
multiple_files = [pd.read_csv(file) for file in allFiles]

# %%
# display multiple files
pd.concat(multiple_files, ignore_index = True)
# Out:
#             age      job_type marital_status education_level  default_or_not  \
# 0     65.000000       retired        married       secondary               0
# 1     36.000000    management        married        tertiary               0
# 2     37.000000    management        married        tertiary               0
# 3     30.065066    management         single        tertiary               0
# 4     41.000000    management        married        tertiary               0
# ...         ...           ...            ...             ...             ...
# 4032  44.000000    technician         single             NaN               0
# 4033  57.000000        admin.        married       secondary               0
# 4034  51.000000  entrepreneur        married        tertiary               0
# 4035  61.000000   blue-collar        married         primary               0
# 4036  53.000000    technician        married       secondary               0
#
# ...

# %% [markdown]
# # HOW TO CONVERT DATE TIME OBJECT TO INTEGER VALUE?

# %%
data['CallDuration'] = pd.to_datetime(data['call_end']) - pd.to_datetime(data['call_start'])

# %%
data['CallDuration'].apply(lambda x: x.seconds) #Getting an integer value for call duration
# Out:
# 0        523
# 1        475
# 2        337
# 3      58467
# 4         65
#        ...
# 930      831
# 931      352
# 932      664
# 933      893
# 934      520
# Name: CallDuration, Length: 935, dtype: int64

# %%
data = data.drop(['call_start', 'call_end'], axis=1)
data
# Out:
#            age     job_type marital_status education_level  default_or_not  \
# 0    65.000000      retired        married       secondary               0
# 1    36.000000   management        married        tertiary               0
# 2    37.000000   management        married        tertiary               0
# 3    30.065066   management         single        tertiary               0
# 4    41.000000   management        married        tertiary               0
# ..         ...          ...            ...             ...             ...
# 930  31.000000  blue-collar        married       secondary               0
# 931  30.000000   technician         single       secondary               0
# 932  42.000000   management        married        tertiary               0
# 933  46.000000     services        married       secondary               0
# 934  54.000000  blue-collar        married       secondary               0
#
#      balance_amt  household_insurance  car_loan communication  \
# ...
